# %%
from bs4 import BeautifulSoup
import requests
import lxml
import time
import json

# %%
headers={'user-agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'}
years = ['2002', '2003', '2004', '2005', '2006', '2007', '2008', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']

# %%
all_picks = []
for y in years:
    url = 'https://www.pro-football-reference.com/years/{}/draft.htm'.format(y)
    r = requests.get(url, headers=headers)
    draftSoup = BeautifulSoup(r.text, 'lxml')
    draftTableSoup = draftSoup.find("table", class_="stats_table")
    tableBodySoup = draftTableSoup.find("tbody")
    for x in tableBodySoup.find_all("tr"):
        if (x.find("td", attrs={"data-stat":"draft_pick"}) is not None):
            draftPick = []
            draftPick.append(y)
            draftPick.append(x.find("th", attrs={"data-stat":"draft_round"}).text)
            draftPick.append(x.find("td", attrs={"data-stat":"draft_pick"}).text)
            draftPick.append(x.find("td", attrs={"data-stat":"team"}).text)       
            draftPick.append(x.find("td", attrs={"data-stat":"player"}).text)
            draftPick.append(x.find("td", attrs={"data-stat":"pos"}).text)
            draftPick.append(x.find("td", attrs={"data-stat":"all_pros_first_team"}).text)
            draftPick.append(x.find("td", attrs={"data-stat":"pro_bowls"}).text)
            draftPick.append(x.find("td", attrs={"data-stat":"years_as_primary_starter"}).text)
            draftPick.append(x.find("td", attrs={"data-stat":"g"}).text)
            draftPick.append(x.find("td", attrs={"data-stat":"college_id"}).text)
            all_picks.append(draftPick)
    time.sleep(10)

# %%
final_nflDraft = []
nfl_keys = ['year', 'draft_round', 'draft_pick', 'team', 'player', 'pos', 'all_pros_first_team', 'pro_bowls', 'years_as_primary_starter', 'g', 'college_id']

for list in all_picks:
    newdict = {nfl_keys[i]: list[i] for i in range(len(nfl_keys))}
    final_nflDraft.append(newdict)
    newdict = {}
# Out:
# [{'year': '2002', 'draft_round': '1', 'draft_pick': '1', 'team': 'HOU', 'player': 'David Carr', 'pos': 'QB', 'all_pros_first_team': '0', 'pro_bowls': '0', 'years_as_primary_starter': '5', 'g': '94', 'college_id': 'Fresno St.'}, {'year': '2002', 'draft_round': '1', 'draft_pick': '2', 'team': 'CAR', 'player': 'Julius Peppers', 'pos': 'DE', 'all_pros_first_team': '3', 'pro_bowls': '9', 'years_as_primary_starter': '16', 'g': '266', 'college_id': 'North Carolina'}, {'year': '2002', 'draft_round': '1', 'draft_pick': '3', 'team': 'DET', 'player': 'Joey Harrington', 'pos': 'QB', 'all_pros_first_team': '0', 'pro_bowls': '0', 'years_as_primary_starter': '6', 'g': '81', 'college_id': 'Oregon'}, {'year': '2002', 'draft_round': '1', 'draft_pick': '4', 'team': 'BUF', 'player': 'Mike Williams', 'pos': 'T', 'all_pros_first_team': '0', 'pro_bowls': '0', 'years_as_primary_starter': '4', 'g': '59', 'college_id': 'Texas'}, {'year': '2002', 'draft_round': '1', 'draft_pick': '5', 'team': 'SDG', 'player': 'Quentin Jammer', 'pos': 'DB', 'all_pros_first_team': '0', 'pro_bowls': '0', 'years_as_primary_starter': '10', 'g': '183', 'college_id': 'Texas'}, {'year': '2002', 'draft_round': '1', 'draft_pick': '6', 'team': 'KAN', 'player': 'Ryan Sims', 'pos': 'DT', 'all_pros_first_team': '0', 'pro_bowls': '0', 'years_as_primary_starter': '3', 'g': '105', 'college_id': 'North Carolina'}, {'year': '2002', 'draft_round': '1', 'draft_pick': '7', 'team': 'MIN', 'player': 'Bryant McKinnie', 'pos': 'T', 'all_pros_first_team': '0', 'pro_bowls': '1', 'years_as_primary_starter': '11', 'g': '179', 'college_id': 'Miami (FL)'}, {'year': '2002', 'draft_round': '1', 'draft_pick': '8', 'team': 'DAL', 'player': 'Roy Williams', 'pos': 'DB', 'all_pros_first_team': '1', 'pro_bowls': '5', 'years_as_primary_starter': '7', 'g': '114', 'college_id': 'Oklahoma'}, {'year': '2002', 'draft_round': '1', 'draft_pick': '9', 'team': 'JAX', 'player': 'John Henderson', 'pos': 'DT', 'all_pros_first_team': '0', 'pro_bowls': '2', 'years_as_primary_starter': '8', 'g': '146', 'college_id': 'Tennessee'}, {'year': '2002', 'draft_round': '1', 'draft_pick': '10', 'team': 'CIN', 'player': 'Levi Jones', 'pos': 'T', 'all_pros_first_team': '0', 'pro_bowls': '0', 'years_as_primary_starter': '7', 'g': '103', 'college_id': 'Arizona St.'}, {'year': '2002', 'draft_round': '1', 'draft_pick': '11', 'team': 'IND', 'player': 'Dwight Freeney', 'pos': 'DE', 'all_pros_first_team': '3', 'pro_bowls': '7', 'years_as_primary_starter': '11', 'g': '218', 'college_id': 'Syracuse'}, {'year': '2002', 'draft_round': '1', 'draft_pick': '12', 'team': 'ARI', 'player': 'Wendell Bryant', 'pos': 'DT', 'all_pros_first_team': '0', 'pro_bowls': '0', 'years_as_primary_starter': '0', 'g': '29', 'college_id': 'Wisconsin'}, {'year': '2002', 'draft_round': '1', 'draft_pick': '13', 'team': 'NOR', 'player': "Donte' Stallworth", 'pos': 'WR', 'all_pros_first_team': '0', 'pro_bowls': '0', 'years_as_primary_starter': '4', 'g': '115', 'college_id': 'Tennessee'}, {'year': '2002', 'draft_round': '1', 'draft_pick': '14', 'team': 'NYG', 'player': 'Jeremy Shockey', 'pos': 'TE', 'all_pros_first_team': '1', 'pro_bowls': '4', 'years_as_primary_starter': '10', 'g': '136', 'college_id': 'Miami (FL)'}, {'year': '2002', 'draft_round': '1', 'draft_pick': '15', 'team': 'TEN', 'player': 'Albert Haynesworth', 'pos': 'DT', 'all_pros_first_team': '2', 'pro_bowls': '2', 'years_as_primary_starter': '7', 'g': '123', 'college_id': 'Tennessee'}, {'year': '2002', 'draft_round': '1', 'draft_pick': '16', 'team': 'CLE', 'player': 'William Green', 'pos': 'RB', 'all_pros_first_team': '0', 'pro_bowls': '0', 'years_as_primary_starter': '3', 'g': '46', 'college_id': 'Boston Col.'}, {'year': '2002', 'draft_round': '1', 'draft_pick': '17', 'team': 'OAK', 'player': 'Phillip Buchanon', 'pos': 'DB', 'all_pros_first_team': '0', 'pro_bowls': '0', 'years_as_primary_starter': '5', 'g': '122', 'college_id': 'Miami (FL)'}, {'year': '2002', 'draft_round': '1', 'draft_pick': '18', 'team': 'AT ...

# %%
with open("..\nfldraft.json", "w") as write_file:
    json.dump(final_nflDraft, write_file)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-14-1b4d8cdb7380> in <module>
# ----> 1 f = open("nfldraft.json", "x")
#       2
#       3 with open("..\nfldraft.json", "w") as write_file:
#       4     json.dump(final_nflDraft, write_file)
#
# FileExistsError: [Errno 17] File exists: 'nfldraft.json'
