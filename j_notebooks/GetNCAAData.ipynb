# %%
from bs4 import BeautifulSoup
import requests
import lxml
import time
import json
import os.path
from os import path
import string

# %%
def requestPage (url):
    headers={'user-agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'}
    r = requests.get(url, headers=headers)
    request = {}
    request['status_code'] = r.status_code
    request['reason'] = r.reason
    request['text'] = r.text
    return request

# %%
#Load NCAA Site Schema
schoolsList = json.loads(open('..//config//schools.json', "r").read())
ncaaDates = json.loads(open('..//config//ncaa_dates.json', "r").read())

# %% [markdown]
# #

# %%
urlDict = []
for x in schoolsList:
    if ('ncaa' in x.keys()):
        thisUrl = {}
        thisUrl['team'] = x['id']
        thisUrl['conference'] = x['conference'][0]
        thisUrl['ncaa'] = 'http://stats.ncaa.org/team/' + x['ncaa'] + '/roster/'
        urlDict.append(thisUrl)
print(urlDict)
# Out:
# [{'team': 'maryland', 'conference': 'bigten', 'ncaa': 'http://stats.ncaa.org/team/392/roster/'}, {'team': 'illinois', 'conference': 'bigten', 'ncaa': 'http://stats.ncaa.org/team/301/roster/'}, {'team': 'indiana', 'conference': 'bigten', 'ncaa': 'http://stats.ncaa.org/team/306/roster/'}, {'team': 'iowa', 'conference': 'bigten', 'ncaa': 'http://stats.ncaa.org/team/312/roster/'}, {'team': 'michigan', 'conference': 'bigten', 'ncaa': 'http://stats.ncaa.org/team/418/roster/'}, {'team': 'michigan-state', 'conference': 'bigten', 'ncaa': 'http://stats.ncaa.org/team/416/roster/'}, {'team': 'minnesota', 'conference': 'bigten', 'ncaa': 'http://stats.ncaa.org/team/428/roster/'}, {'team': 'northwestern', 'conference': 'bigten', 'ncaa': 'http://stats.ncaa.org/team/463/roster/'}, {'team': 'ohio-state', 'conference': 'bigten', 'ncaa': 'http://stats.ncaa.org/team/518/roster/'}, {'team': 'penn-state', 'conference': 'bigten', 'ncaa': 'http://stats.ncaa.org/team/539/roster/'}, {'team': 'purdue', 'conference': 'bigten', 'ncaa': 'http://stats.ncaa.org/team/559/roster/'}, {'team': 'rutgers', 'conference': 'bigten', 'ncaa': 'http://stats.ncaa.org/team/587/roster/'}, {'team': 'wisconsin', 'conference': 'bigten', 'ncaa': 'http://stats.ncaa.org/team/796/roster/'}, {'team': 'alabama', 'conference': 'sec', 'ncaa': 'http://stats.ncaa.org/team/8/roster/'}, {'team': 'arkansas', 'conference': 'sec', 'ncaa': 'http://stats.ncaa.org/team/31/roster/'}, {'team': 'auburn', 'conference': 'sec', 'ncaa': 'http://stats.ncaa.org/team/37/roster/'}, {'team': 'florida', 'conference': 'sec', 'ncaa': 'http://stats.ncaa.org/team/235/roster/'}, {'team': 'georgia', 'conference': 'sec', 'ncaa': 'http://stats.ncaa.org/team/257/roster/'}, {'team': 'kentucky', 'conference': 'sec', 'ncaa': 'http://stats.ncaa.org/team/334/roster/'}, {'team': 'lsu', 'conference': 'sec', 'ncaa': 'http://stats.ncaa.org/team/365/roster/'}, {'team': 'ole-miss', 'conference': 'sec', 'ncaa': 'http://stats.ncaa.org/team/433/roster/'}, {'team': 'mississippi-state', 'conference': 'sec', 'ncaa': 'http://stats.ncaa.org/team/430/roster/'}, {'team': 'missouri', 'conference': 'sec', 'ncaa': 'http://stats.ncaa.org/team/434/roster/'}, {'team': 'south-carolina', 'conference': 'sec', 'ncaa': 'http://stats.ncaa.org/team/648/roster/'}, {'team': 'tennessee', 'conference': 'sec', 'ncaa': 'http://stats.ncaa.org/team/694/roster/'}, {'team': 'texas-am', 'conference': 'sec', 'ncaa': 'http://stats.ncaa.org/team/697/roster/'}, {'team': 'vanderbilt', 'conference': 'sec', 'ncaa': 'http://stats.ncaa.org/team/736/roster/'}, {'team': 'baylor', 'conference': 'bigtwelve', 'ncaa': 'http://stats.ncaa.org/team/522/roster/'}, {'team': 'iowa-state', 'conference': 'bigtwelve', 'ncaa': 'http://stats.ncaa.org/team/311/roster/'}, {'team': 'kansas', 'conference': 'bigtwelve', 'ncaa': 'http://stats.ncaa.org/team/328/roster/'}, {'team': 'oklahoma', 'conference': 'bigtwelve', 'ncaa': 'http://stats.ncaa.org/team/327/roster/'}, {'team': 'oklahoma-state', 'conference': 'bigtwelve', 'ncaa': 'http://stats.ncaa.org/team/521/roster/'}, {'team': 'tcu', 'conference': 'bigtwelve', 'ncaa': 'http://stats.ncaa.org/team/698/roster/'}, {'team': 'texas', 'conference': 'bigtwelve', 'ncaa': 'http://stats.ncaa.org/team/703/roster/'}, {'team': 'texas-tech', 'conference': 'bigtwelve', 'ncaa': 'http://stats.ncaa.org/team/700/roster/'}, {'team': 'west-virginia', 'conference': 'bigtwelve', 'ncaa': 'http://stats.ncaa.org/team/768/roster/'}]

# %%
for x in urlDict:
    for year in ncaaDates:
        request = requestPage(x['ncaa'] + year['id'])
        print(x['team'] + ' ' + year['id'] + ':' + str(request['status_code']))
        if (request['status_code'] == 200):
            with open("..//html//ncaa//" + x['conference'] + "//rosters//" + x['team'] + "_" + year['year'] + ".html", "w", encoding="utf-8") as write_file:
                write_file.write(request['text'])
        time.sleep(6)
# Out:
# maryland 11520:200
# maryland 11980:200
# maryland 12240:200
# maryland 12424:200
# maryland 12623:200
# maryland 14280:200
# maryland 14900:200
# maryland 15280:200
# illinois 11520:200
# illinois 11980:200
# illinois 12240:200
# illinois 12424:200
# illinois 12623:200
# illinois 14280:200
# illinois 14900:200
# illinois 15280:200
# indiana 11520:200
# indiana 11980:200
# indiana 12240:200
# indiana 12424:200
# indiana 12623:200
# indiana 14280:200
# indiana 14900:200
# indiana 15280:200
# iowa 11520:200
# iowa 11980:200
# iowa 12240:200
# iowa 12424:200
# iowa 12623:200
# iowa 14280:200
# iowa 14900:200
# iowa 15280:200
# michigan 11520:200
# michigan 11980:200
# michigan 12240:200
# michigan 12424:200
# michigan 12623:200
# michigan 14280:200
# michigan 14900:200
# michigan 15280:200
# michigan-state 11520:200
# michigan-state 11980:200
# michigan-state 12240:200
# michigan-state 12424:200
# michigan-state 12623:200
# michigan-state 14280:200
# michigan-state 14900:200
# michigan-state 15280:200
# minnesota 11520:200
# minnesota 11980:200
# minnesota 12240:200
# minnesota 12424:200
# minnesota 12623:200
# minnesota 14280:200
# minnesota 14900:200
# minnesota 15280:200
# northwestern 11520:200
# northwestern 11980:200
# northwestern 12240:200
# northwestern 12424:200
# northwestern 12623:200
# northwestern 14280:200
# northwestern 14900:200
# northwestern 15280:200
# ohio-state 11520:200
# ohio-state 11980:200
# ohio-state 12240:200
# ohio-state 12424:200
# ohio-state 12623:200
# ohio-state 14280:200
# ohio-state 14900:200
# ohio-state 15280:200
# penn-state 11520:200
# penn-state 11980:200
# penn-state 12240:200
# penn-state 12424:200
# penn-state 12623:200
# penn-state 14280:200
# penn-state 14900:200
# penn-state 15280:200
# purdue 11520:200
# purdue 11980:200
# purdue 12240:200
# purdue 12424:200
# purdue 12623:200
# purdue 14280:200
# purdue 14900:200
# purdue 15280:200
# rutgers 11520:200
# rutgers 11980:200
# rutgers 12240:200
# rutgers 12424:200
# rutgers 12623:200
# rutgers 14280:200
# rutgers 14900:200
# rutgers 15280:200
# wisconsin 11520:200
# wisconsin 11980:200
# wisconsin 12240:200
# wisconsin 12424:200
# wisconsin 12623:200
# wisconsin 14280:200
# wisconsin 14900:200
# wisconsin 15280:200
# alabama 11520:200
# alabama 11980:200
# alabama 12240:200
# alabama 12424:200
# alabama 12623:200
# alabama 14280:200
# alabama 14900:200
# alabama 15280:200
# arkansas 11520:200
# arkansas 11980:200
# arkansas 12240:200
# arkansas 12424:200
# arkansas 12623:200
# arkansas 14280:200
# arkansas 14900:200
# arkansas 15280:200
# auburn 11520:200
# auburn 11980:200
# auburn 12240:200
# auburn 12424:200
# auburn 12623:200
# auburn 14280:200
# auburn 14900:200
# auburn 15280:200
# florida 11520:200
# florida 11980:200
# florida 12240:200
# florida 12424:200
# florida 12623:200
# florida 14280:200
# florida 14900:200
# florida 15280:200
# georgia 11520:200
# georgia 11980:200
# georgia 12240:200
# georgia 12424:200
# georgia 12623:200
# georgia 14280:200
# georgia 14900:200
# georgia 15280:200
# kentucky 11520:200
# kentucky 11980:200
# kentucky 12240:200
# kentucky 12424:200
# kentucky 12623:200
# kentucky 14280:200
# kentucky 14900:200
# kentucky 15280:200
# lsu 11520:200
# lsu 11980:200
# lsu 12240:200
# lsu 12424:200
# lsu 12623:200
# lsu 14280:200
# lsu 14900:200
# lsu 15280:200
# ole-miss 11520:200
# ole-miss 11980:200
# ole-miss 12240:200
# ole-miss 12424:200
# ole-miss 12623:200
# ole-miss 14280:200
# ole-miss 14900:200
# ole-miss 15280:200
# mississippi-state 11520:200
# mississippi-state 11980:200
# mississippi-state 12240:200
# mississippi-state 12424:200
# mississippi-state 12623:200
# mississippi-state 14280:200
# mississippi-state 14900:200
# mississippi-state 15280:200
# missouri 11520:200
# missouri 11980:200
# missouri 12240:200
# missouri 12424:200
# missouri 12623:200
# missouri 14280:200
# missouri 14900:200
# missouri 15280:200
# south-carolina 11520:200
# south-carolina 11980:200
# south-carolina 12240:200
# south-carolina 12424:200
# south-carolina 12623:200
# south-carolina 14280:200
# south-carolina 14900:200
# south-carolina 15280:200
# tennessee 11520:200
# tennessee 11980:200
# tennessee 12240:200
# tennessee 12424:200
# tennessee 12623:200
# tennessee 14280:200
# tennessee 14900:200
# tennessee 15280:200
# texas-am 11520:200
# texas-am 11980:200
# texas-am 12240:200
# texas-am 12424:200
# texas-am 12623:200
# texas-am 14280:200
# texas-am 14900:200
# texas-am 15280:200
# vanderbilt 11520:200
# vanderbilt 11980:200
# vanderbilt 12240:200
# vanderbilt 12424:200
# vanderbilt 12623:200
# vanderbilt 14280:200
# vanderbilt 14900:200
# vanderbilt 15280:200
# baylor 11520:200
# baylor 11980:200
# baylor 12240:200
# baylor 12424:200
# baylor 12623:200
# baylor 14280:200
# baylor 14900:200
# baylor 15280:200
# iowa-state 11520:200
# iowa-state 11980:200
# iowa-state 12240:200
# iowa-state 12424:200
# iowa-state 12623:200
# iowa-state 14280:200
# iowa-state 14900:200
# iowa-state 15280:200
# kansas 11520:200
# kansas 11980:200
# kansas 12240:200
# kansas 12424:200
# kansas 12623:200
# kansas 14280:200
# kansas 14900:200
# kansas 15280:200
# oklahoma 11520:200
# oklahoma 11980:200
# oklahoma 12240:200
# oklahoma 12424:200
# oklahoma 12623:200
# oklahoma 14280:200
# oklahoma 14900:200
# oklahoma 15280:200
# oklahoma-state 11520:200
# oklahoma-state 11980:200
# oklahoma-state 12240:200
# oklahoma-state 12424:200
# oklahoma-state 12623:200
# oklahoma-state 14280:200
# oklahoma-state 14900:200
# oklahoma-state 15280:200
# tcu 11520:200
# tcu 11980:200
# tcu 12240:200
# tcu 12424:200
# tcu 12623:200
# tcu 14280:200
# tcu 14900:200
# tcu 15280:200
# texas 11520:200
# texas 11980:200
# texas 12240:200
# texas 12424:200
# texas 12623:200
# texas 14280:200
# texas 14900:200
# texas 15280:200
# texas-tech 11520:200
# texas-tech 11980:200
# texas-tech 12240:200
# texas-tech 12424:200
# texas-tech 12623:200
# texas-tech 14280:200
# texas-tech 14900:200
# texas-tech 15280:200
# west-virginia 11520:200
# west-virginia 11980:200
# west-virginia 12240:200
# west-virginia 12424:200
# west-virginia 12623:200
# west-virginia 14280:200
# west-virginia 14900:200
# west-virginia 15280:200
